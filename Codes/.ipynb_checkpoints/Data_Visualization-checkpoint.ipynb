# %% [markdown]
# ## Importing necessary libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  Changing the working directory

# %%
os.chdir("D:\DM7\Python for Data Science\Data_Files")

# %% [markdown]
# ## Importing data

# %%
cars_data = pd.read_csv('cleaned_cars_data.csv', index_col=0)
cars_data.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %% [markdown]
# ## Popular plotting libraries in Python
# 1. matplotlib - to create 2D graphs and plots
# 2. pandas visualization - easy to use interface, built on Matplotlib
# 3. seaborn - provides a high-level interface for drawing attractive and informative statistical graphics
# 4. ggplot - based on R’s ggplot2, uses Grammar of Graphics
# 5. plotly - can create interactive plots

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# What is a scatter plot?
# 1. A scatter plot is a set of points that represents the values obtained for two different variables plotted on a horizontal and vertical axes

# %% [markdown]
# When to use scatter plots?
# 1. Scatter plots are used to convey the relationship between two numerical variables
# 2. Scatter plots are sometimes called correlationplots because they show how two variables arecorrelated

# %%
plt.scatter(cars_data['Age'], cars_data['Price'], c='red')
plt.title('Scatter plot of Price vs Age of Cars')
plt.xlabel('Age(Months)')
plt.ylabel('Price(Euros)')
plt.show()

# %% [markdown]
# #### Conclusion - The price of the car decreases as age of the car increases

# %% [markdown]
# ### Scatter plot with Seaborn Library

# %% [markdown]
# Scatter plot of Price vs Age by customizing the appearance of markers

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = cars_data['Age'], y=cars_data['Price'], marker = '*')
plt.title('Scatter plot of Price vs Age of Cars')
plt.xlabel('Age(Months)')
plt.ylabel('Price(Euros)')
plt.show()

# %% [markdown]
# ### Scatter plot of Price vs Age by FuelType

# %% [markdown]
# Using hue parameter, including another variable to show the fuel
# types categories with different colors

# %%
sns.lmplot(x='Age', y='Price', data=cars_data,
          fit_reg=False, hue='FuelType',
          legend=True, palette='Set1')
plt.title('Scatter plot of Price vs Age by FuelType')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Price vs Age by FuelType')

# %% [markdown]
# ## Histogram

# %% [markdown]
# What is a histogram?
# 1. It is a graphical representation of data usingbars of different heights
# 2. Histogram groups numbers into ranges andthe height of each bar depicts the frequency of each range or bin

# %% [markdown]
# When to use histograms?
# 1. To represent the frequency distribution of mnumerical variables

# %%
plt.hist(cars_data['KM'], color='green', edgecolor = 'white' , bins= 5)
plt.title("Histogram of Kilometer")
plt.xlabel("Kilometer")
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Conclusion : Frequency distribution of kilometre of the cars shows that most of the cars have travelled between 50000 – 100000 km and there are only few cars with more distance travelled

# %%
sns.distplot(cars_data['Age'],  bins= 5)
plt.title('Histogram of Age')
plt.show()
# Out:
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_24960\1935579874.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Age'],  bins= 5)

# %% [markdown]
# ## Bar plot

# %% [markdown]
# What is a bar plot?
# 1. A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the counts that they represent

# %% [markdown]
# When to use bar plot?
# 1. To represent the frequency distribution of categorical variables
# 2. A bar diagram makes it easy to compare sets of data between different groups

# %%
cars_data['FuelType'].value_counts()
# Out:
# Petrol    1277
# Diesel     144
# CNG         15
# Name: FuelType, dtype: int64

# %%
counts = [1277, 144, 15]
fuelType = ('Petrol','Diesel', 'CNG')
index = np.arange(len(fuelType))

# %%
plt.bar(index, counts, color = ['red','blue','cyan'])
plt.title('Bar plot of fuel types')
plt.xlabel('Fuel Types')
plt.ylabel('Frequency')
plt.xticks(index, fuelType, rotation = 90)
plt.show()

# %% [markdown]
# #### Conclusion - Bar plot of fuel type shows that most of the cars have petrol as fuel type

# %% [markdown]
# ### With Seaborn library

# %% [markdown]
# Frequency distribution of fuel type

# %%
sns.countplot(x='FuelType', data = cars_data)
plt.title('Bar plot of fuel types')
plt.show()

# %% [markdown]
# ## Grouped bar plot

# %% [markdown]
# Grouped bar plot of FuelType and Automatic

# %%
sns.countplot(x='FuelType', data = cars_data, hue='Automatic')
plt.title('Grouped bar plot of FuelType and Automatic')
plt.show()

# %% [markdown]
# ## Box and whiskers plot – numerical variable

# %% [markdown]
# Box and whiskers plot of Price to visually interpret the five-number summary

# %%
sns.boxplot(y = cars_data['Price'])
# Out:
# <AxesSubplot: ylabel='Price'>

# %% [markdown]
# ## Box and whiskers plot for numerical vs categorical variable

# %% [markdown]
# Price of the cars for various fuel types

# %%
sns.boxplot(y = cars_data['Price'], x = cars_data['FuelType'])
plt.title('Price of the cars for various fuel types')
plt.show()

# %% [markdown]
# ## Grouped box and whiskers plot

# %% [markdown]
# Grouped box and whiskers plot of Price vs FuelType and Automatic

# %%
sns.boxplot(x = 'FuelType', y = 'Price', data = cars_data, hue='Automatic')
plt.title('Grouped box and whiskers plot of Price vs FuelType and Automatic')
plt.show()

# %% [markdown]
# ## Box-whiskers plot and Histogram

# %% [markdown]
# 1. Let’s plot box-whiskers plot and histogram on the same window
# 2. Split the plotting window into 2 parts then add create two plots

# %%
f, (ax_box, ax_hist) = plt.subplots(2, gridspec_kw={'height_ratios':(0.30, 0.70)})
sns.boxplot(cars_data['Price'], ax= ax_box)
sns.distplot(cars_data['Price'], ax= ax_hist, kde=False)
# Out:
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_24960\2917216193.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_data['Price'], ax= ax_hist, kde=False)
# <AxesSubplot: xlabel='Price'>

# %% [markdown]
# ## Pairwise plots

# %% [markdown]
# 1. It is used to plot pairwise relationships in a dataset
# 2. Creates scatterplots for joint relationships and histograms for univariate distributions

# %%
sns.pairplot(cars_data, kind='scatter', hue='FuelType')
plt.show()
